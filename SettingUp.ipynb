# %% [markdown]
# # Deep Learning and Image with Python

# %% [markdown]
# # Installation
# ![image.png](attachment:image.png)

# %% [markdown]
# # Set path of python in environment variable,
# C:\Users\...\AppData\Local\Programs\Python\Python36\Scripts\
#
# C:\Users\...\AppData\Local\Programs\Python\Python36\

# %% [markdown]
# # Cuda-Installation
# http://docs.nvidia.com/deeplearning/sdk/cudnn-install/index.html
# # install nvdia driver
# http://www.nvidia.com/content/DriverDownload-March2009/confirmation.php?url=/Windows/391.01/391.01-desktop-win10-64bit-international-whql.exe&lang=us&type=TITAN
# # install CUDA toolkit V9.0 compattiple check with tensorFlow
# https://www.tensorflow.org/install/install_windows
# install cuda v.8 for tensorflow. If driver is not compatible, please continue.
# # when run tensorflow and have the problem "cudnn64_?.dll" go to
# https://developer.nvidia.com/rdp/cudnn-download
# # check path
# Variable name: CUDA_PATH, Variable value: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v9.0

# %% [markdown]
# # Set TensorFlow backend in keras.json
#
# C:\Users\...\.keras\keras.json
#
# {
#
#     "floatx": "float32",
#
#     "epsilon": 1e-07,
#
#     "backend": "tensorflow",
#
#     "image_data_format": "channels_last"
#
# }

# %% [markdown]
# # Learning links
# https://github.com/keras-team/keras/tree/master/examples
#
# https://www.learnopencv.com/image-classification-using-convolutional-neural-networks-in-keras/
#
# https://machinelearningmastery.com/handwritten-digit-recognition-using-convolutional-neural-networks-python-keras/
#
# https://www.datacamp.com/community/tutorials/deep-learning-python?utm_source=adwords_ppc&utm_campaignid=1455363063&utm_adgroupid=65083631748&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=1t1&utm_creative=278443377077&utm_targetid=dsa-473406573755&utm_loc_interest_ms=&utm_loc_physical_ms=9047113&gclid=EAIaIQobChMI6dXQk6Ok3gIVkgsrCh2Hng5rEAAYASAAEgJilPD_BwE#modeling

# %% [markdown]
# # Artificial Neural Network
# image from https://www.datacamp.com/community/tutorials/deep-learning-python?utm_source=adwords_ppc&utm_campaignid=1455363063&utm_adgroupid=65083631748&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=1t1&utm_creative=278443377077&utm_targetid=dsa-473406573755&utm_loc_interest_ms=&utm_loc_physical_ms=9047113&gclid=EAIaIQobChMI6dXQk6Ok3gIVkgsrCh2Hng5rEAAYASAAEgJilPD_BwE#modeling
#
# ![image.png](attachment:image.png)
